# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - The above is 11 because the root of the tree is not a complete subtree (since the last layer is not filled from left to right), and the node with no children that is not in the last layer is also not a complete subtree

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
